# %%
# Data origin: https://github.com/kjanjua26/jurassic-park
import pandas as pd
import altair as alt

# %%
dinos = pd.read_csv("dinosaurs.csv")
dinos.describe()
# Out:
#             name         diet                                   period  \
# count        309          309                                      308
# unique       309            5                                      153
# top     aardonyx  herbivorous  Late Cretaceous 76-74 million years ago
# freq           1          185                                       14
#
#        lived_in      type length  \
# count       309       308    292
# unique       32         6     73
# top         USA  sauropod   6.0m
# freq         78        69     21
#
#                                                  taxonomy      named_by  \
# count                                                 309           309
# unique                                                102           277
# top     Dinosauria Ornithischia Genasauria Cerapoda Or...  Marsh (1877)
# freq                                                   11             4
#
#              species                                               link
# count            304                                                309
# unique           272                                                309
# top     mongoliensis  https://www.nhm.ac.uk/discover/dino-directory/...
# freq               7                                                  1

# %%
dinos["length"] = [(float(s[:-1]) if ('m' in str(s)) else None) for s in dinos["length"]]

# %%
dinos["time_from"] = [(int(s.split()[-4].split("-")[0]) if (s and ("million years ago" in str(s))) else None) for s in dinos["period"]]
dinos["time_to"] = [(int(s.split()[2].split("-")[-1]) if (s and ("million years ago" in str(s))) else None) for s in dinos["period"]]
dinos["Order"] = ["".join(s.split()[1:2]) or "" for s in dinos["taxonomy"]]
dinos["Family"] =dinos["Order"] +":"+ ["".join(s.split()[2:3]) or "Other" for s in dinos["taxonomy"]]
# dinos = dinos[dinos["Order"]!=":Other"][not(dinos["time_from"] is None)]
dinos = dinos.dropna()
dinos[['time_from', 'time_to', "Order", "Family"]].head()
# Out:
#    time_from  time_to         Order                      Family
# 0      199.0    189.0    Saurischia  Saurischia:Sauropodomorpha
# 1       74.0     70.0    Saurischia        Saurischia:Theropoda
# 2       83.0     70.0  Ornithischia     Ornithischia:Genasauria
# 3       99.0     84.0    Saurischia        Saurischia:Theropoda
# 4      115.0    105.0    Saurischia        Saurischia:Theropoda

# %%
periods = pd.DataFrame({"period":['Triassic', 'Jurassic', 'Cretaceous'], 'start':[232, 201, 145], 'end':[201, 145, 65]})
periods
# Out:
#        period  start  end
# 0    Triassic    232  201
# 1    Jurassic    201  145
# 2  Cretaceous    145   65

# %%
# General plot: existance intervals for each species

points1 = alt.Chart().mark_point().encode(
    x = "time_from:Q",
)
points2 = alt.Chart().mark_point().encode(
    x = "time_to:Q",
)
lines = alt.Chart().mark_line().encode(
    x = alt.X("time_from:Q", title='Time, millions years ago'),
    x2 = "time_to:Q",
)

len_time_chart = (points1 + points2 + lines).encode(
        y=alt.Y("length_j:Q"),
    tooltip = [alt.Tooltip("name:N"),alt.Tooltip("period:N")],
    color = alt.Color("type:N",
            scale=alt.Scale(scheme='dark2')
            )
)

period_rects = alt.Chart(periods).mark_rect(opacity=0.1).encode(
    x2=alt.X2('start:Q'),
    x=alt.X('end:Q', title=None),
    color=alt.Color('period:N',
    #  legend=False
        scale=alt.Scale(scheme='set1')
     )
)
alt.layer(period_rects, len_time_chart, data=dinos
).transform_calculate(
    # Generate Gaussian jitter with a Box-Muller transform
    length_j='datum.length + abs(sqrt(-0.5*log(random()))*cos(2*PI*random()))'
).configure_scale(
    xReverse=True
).resolve_scale(
    color='independent'
).configure_line(

).properties(
    width = 1100, height=500
)
# Out:
# alt.LayerChart(...)

# %%
# How big were they? length distriution by main families; Sauropodomorpha are the biggest; Therapoeas are mostly small with few large exceptions

alt.Chart(dinos).transform_density(
    density='length',
    groupby=['Family'],
    counts=True
    # extent= [0, 8]
).mark_line().encode(
    x = alt.X("value:Q", title="Length, m"),
    y = alt.Y("density:Q"),
    color=alt.Color("Family:N")
).properties(width = 1100, height=500)
# Out:
# alt.Chart(...)

# %%
dinos_expanded = pd.concat([pd.DataFrame({'time': [*range(round(row.time_to), round(row.time_from)+1)],
            'taxonomy': row.taxonomy,
            'name':row.name,
            'length':row.length,
            'type':row.type,
            'Family':row.Family
            }, columns=['time', 'name','taxonomy', 'length', 'type', "Family"]) 
        for i, row in dinos.iterrows()], ignore_index=True)
dinos_expanded["Genus"] = ["".join(tax.split(" ")[3:4]) or "" for tax in dinos_expanded["taxonomy"]]
# pd.concat([pd.DataFrame({'time': row.time,
#             'taxonomy': row.taxonomy,
#             }, columns=['time', 'taxonomy']) 
#         for i, row in dinos.iterrows()], ignore_index=True)
# dinos_tax
dinos_expanded
# Out:
#        time  name                                           taxonomy  length  \
# 0     189.0     0  Dinosauria Saurischia Sauropodomorpha Prosauro...     8.0
# 1     190.0     0  Dinosauria Saurischia Sauropodomorpha Prosauro...     8.0
# 2     191.0     0  Dinosauria Saurischia Sauropodomorpha Prosauro...     8.0
# 3     192.0     0  Dinosauria Saurischia Sauropodomorpha Prosauro...     8.0
# 4     193.0     0  Dinosauria Saurischia Sauropodomorpha Prosauro...     8.0
# ...     ...   ...                                                ...     ...
# 2780  116.0   307  Dinosauria Ornithischia Genasauria Cerapoda Or...     1.8
# 2781  117.0   307  Dinosauria Ornithischia Genasauria Cerapoda Or...     1.8
# 2782  118.0   307  Dinosauria Ornithischia Genasauria Cerapoda Or...     1.8
# 2783  119.0   307  Dinosauria Ornithischia Genasauria Cerapoda Or...     1.8
# 2784  120.0   307  Dinosauria Ornithischia Genasauria Cerapoda Or...     1.8
#
#               type                      Family         Genus
# 0         sauropod  Saurischia:Sauropodomorpha  Prosauropoda
# 1         sauropod  Saurischia:Sauropodomorpha  Prosauropoda
# 2         sauropod  Saurischia:Sauropodomorpha  Prosauropoda
# 3         sauropod  Saurischia:Sauropodomorpha  Prosauropoda
# 4         sauropod  Saurischia:Sauropodomorpha  Prosauropoda
# ...            ...                         ...           ...
# 2780  euornithopod     Ornithischia:Genasauria      Cerapoda
# 2781  euornithopod     Ornithischia:Genasauria      Cerapoda
# 2782  euornithopod     Ornithischia:Genasauria      Cerapoda
# 2783  euornithopod     Ornithischia:Genasauria      Cerapoda
# 2784  euornithopod     Ornithischia:Genasauria      Cerapoda
#
# [2785 rows x 7 columns]

# %%
# Number of species in different clades over time
dinos_expanded["Clade1"] = ["-".join(tax.split(" ")[3:4]) or (
    "Unknown "+"-".join(tax.split(" ")[1:])) for tax in dinos_expanded["taxonomy"]]
dinos_expanded["Clade2"] = [
    "-".join(tax.split(" ")[3:5]) or "Unknown" for tax in dinos_expanded["taxonomy"]]
dinos_expanded["Clade3"] = [
    "-".join(tax.split(" ")[3:6]) or "Unknown" for tax in dinos_expanded["taxonomy"]]

scheme = [
# Cerapoda
"#393b79" ,"#5254a3" ,"#6b6ecf" ,
# "#9c9ede" ,
"#31a354",
# Neotheropoda
"#843c39" ,"#ad494a" ,"#d6616b" ,"#e7969c" ,
# Prosauropoda
"#637939" ,"#8ca252","#b5cf6b" ,
# "#cedb9c" ,
# de9ed6
# Sauropoda
"#8c6d31" ,"#bd9e39" ,"#e7ba52" ,
# "#e7cb94" ,
# Thyreophora
"#7b4173" ,"#a55194" ,"#ce6dbd" , "#de9ed6", 
    '#636363'
]
chart_geni = alt.Chart(dinos_expanded).mark_area(interpolate="monotone", point=True).encode(
    # catmull-rom, monotone
    # ['basis', 'basis-open', 'basis-closed', 'bundle', 'cardinal', 'cardinal-open', 'cardinal-closed', 'catmull-rom', 'linear', 'linear-closed', 'monotone', 'natural', 'step', 'step-before', 'step-after']
    x=alt.X('time:Q',
            title='Time, millions years ago',
            bin=alt.Bin(step=10)),
    color=alt.Color('Clade2:N',
                    sort=alt.Sort(field='Clade2', order='ascending'),
                    scale=alt.Scale(
                        range=scheme
                        # scheme= 'category20'
                        )
                    ),
    tooltip='Clade2:N',
    y=alt.Y(
        'distinct(name):Q',
        axis=alt.Axis(),
        stack='zero'
        # stack='center'
    ),
    order=alt.Order('distinct(name):Q')

)
(chart_geni+period_rects).resolve_scale(
    color='independent'
).configure_scale(
    xReverse=True
).properties(width=1100, height=500)
# Out:
# alt.LayerChart(...)

# %%
chart_counts = alt.Chart().mark_bar(orient='vertical', opacity=0.7).encode(
    x=alt.X('time:Q', title='Time, millions years ago'),
    color=alt.Color('Clade2:N',
                    scale=alt.Scale(scheme='dark2')
                    ),
    y=alt.Y(
        'distinct(name):Q',
        stack='center',
        impute=None,
        title="Species",
        axis=None,
    ),
)

alt.layer(
    chart_counts, period_rects, data=dinos_expanded
).resolve_scale(
    color='independent'
).properties(
    width=1100, height=70
).facet(
    row=alt.Row(
        'type:N',
        header=alt.Header(
            titleOrient='bottom',
            labelOrient='bottom',
            labelPadding=0,
        ))
).configure_facet(
    spacing=0
).configure_scale(
    xReverse=True
)
# Out:
# alt.FacetChart(...)

# %%
# How size of different dinosour groups changed over time? Steady growth of Sauropods is seen with peak near beginning and middle of Cretaceous period
chart_lt = alt.Chart(dinos_expanded).mark_line(interpolate="monotone", point=True).encode(
    x=alt.X('time:Q',bin=alt.Bin(step=5), title='Time, millions years ago'),
    color=alt.Color('Clade1:N'),
    y=alt.Y(
        'mean(length):Q',
        title='Average length',
    ),
)
# chart_lt_total = alt.Chart(dinos_expanded).mark_line(interpolate="monotone", point=True).encode(
#     x=alt.X('time:Q',bin=alt.Bin(step=5), title='Time, millions years ago'),
#     y=alt.Y(
#         'mean(length):Q',
#         title='Average length',
#     ),
# )

(chart_lt+period_rects).resolve_scale(
    color='independent'
).configure_scale(
    xReverse=True
).properties(width = 1100, height=500)
# Out:
# alt.LayerChart(...)
